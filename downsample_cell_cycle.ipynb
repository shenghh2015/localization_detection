# %%
import numpy as np
import os
import glob
from skimage import io
import matplotlib.pyplot as plt
from helper_function import print_yellow, print_green, print_red, generate_folder
import scipy.ndimage as ndimage

def get_ax(rows=1, cols=1, size=16):
    """Return a Matplotlib Axes array to be used in
    all visualizations in the notebook. Provide a
    central point to control graph sizes.
    
    Adjust the size attribute to control how big to render images
    """
    fig, ax = plt.subplots(rows, cols, figsize=(size*cols, size*rows))
    fig.tight_layout()
    SMALL_SIZE = 24
    MEDIUM_SIZE = 24
    BIGGER_SIZE = 24

    plt.rc('font', size=SMALL_SIZE)          # controls default text sizes
    plt.rc('axes', titlesize=SMALL_SIZE)     # fontsize of the axes title
    plt.rc('axes', labelsize=MEDIUM_SIZE)    # fontsize of the x and y labels
    plt.rc('xtick', labelsize=SMALL_SIZE)    # fontsize of the tick labels
    plt.rc('ytick', labelsize=SMALL_SIZE)    # fontsize of the tick labels
    plt.rc('legend', fontsize=SMALL_SIZE)    # legend fontsize
    plt.rc('figure', titlesize=BIGGER_SIZE)  # fontsize of the figure title
    return fig, ax

# %%
def generate_folder(folder):
    if not os.path.exists(folder):
        os.system('mkdir -p {}'.format(folder))

## downsample the training data
segmentation_data_folder = '/home/sh38/segmentation_models/phase_cells/data/cell_cycle/'
downsample_data_folder = '/home/sh38/segmentation_models/phase_cells/data/cell_cycle_down2/'
# train, val, test
subset = 'test'
generate_folder(downsample_data_folder+subset+'_images')
generate_folder(downsample_data_folder+subset+'_masks')
images_folder = segmentation_data_folder+'{}_images/'.format(subset)
masks_folder = segmentation_data_folder+'{}_masks/'.format(subset)
print(images_folder); print(masks_folder)
image_files = glob.glob(images_folder+'*.png')

for image_file in image_files:
    # image_file = image_files[100]
    file_name = os.path.basename(image_file)
    mask_file = masks_folder+'{}'.format(file_name)
    print(file_name)
    image = io.imread(image_file); mask = io.imread(mask_file)
    img_down = image[::2,::2]; mask_down = mask[::2,::2]
    down_images_folder = downsample_data_folder+'{}_images/'.format(subset)
    down_masks_folder = downsample_data_folder+'{}_masks/'.format(subset)
    down_image_file = down_images_folder+'{}'.format(file_name)
    down_mask_file = down_masks_folder+'{}'.format(file_name)
    io.imsave(down_image_file, img_down); io.imsave(down_mask_file, mask_down)

_, ax = get_ax(1,2,5)
ax[0].imshow(img_down); ax[1].imshow(mask_down)
_, ax = get_ax(1,2,5)
ax[0].imshow(io.imread(down_image_file)); ax[1].imshow(io.imread(down_mask_file))
print(np.unique(io.imread(down_mask_file)))
# Out:
# /home/sh38/segmentation_models/phase_cells/data/cell_cycle/test_images/
# /home/sh38/segmentation_models/phase_cells/data/cell_cycle/test_masks/
# 0301.png
# /home/sh38/anaconda3/envs/proGAN_tf/lib/python3.6/site-packages/ipykernel_launcher.py:28: UserWarning: /home/sh38/segmentation_models/phase_cells/data/cell_cycle_down2/test_masks/0301.png is a low contrast image
# 0440.png
# /home/sh38/anaconda3/envs/proGAN_tf/lib/python3.6/site-packages/ipykernel_launcher.py:28: UserWarning: /home/sh38/segmentation_models/phase_cells/data/cell_cycle_down2/test_masks/0440.png is a low contrast image
# 0574.png
# /home/sh38/anaconda3/envs/proGAN_tf/lib/python3.6/site-packages/ipykernel_launcher.py:28: UserWarning: /home/sh38/segmentation_models/phase_cells/data/cell_cycle_down2/test_masks/0574.png is a low contrast image
# 0792.png
# /home/sh38/anaconda3/envs/proGAN_tf/lib/python3.6/site-packages/ipykernel_launcher.py:28: UserWarning: /home/sh38/segmentation_models/phase_cells/data/cell_cycle_down2/test_masks/0792.png is a low contrast image
# 0624.png
# /home/sh38/anaconda3/envs/proGAN_tf/lib/python3.6/site-packages/ipykernel_launcher.py:28: UserWarning: /home/sh38/segmentation_models/phase_cells/data/cell_cycle_down2/test_masks/0624.png is a low contrast image
# 0251.png
# /home/sh38/anaconda3/envs/proGAN_tf/lib/python3.6/site-packages/ipykernel_launcher.py:28: UserWarning: /home/sh38/segmentation_models/phase_cells/data/cell_cycle_down2/test_masks/0251.png is a low contrast image
# 0721.png
# /home/sh38/anaconda3/envs/proGAN_tf/lib/python3.6/site-packages/ipykernel_launcher.py:28: UserWarning: /home/sh38/segmentation_models/phase_cells/data/cell_cycle_down2/test_masks/0721.png is a low contrast image
# 0325.png
# /home/sh38/anaconda3/envs/proGAN_tf/lib/python3.6/site-packages/ipykernel_launcher.py:28: UserWarning: /home/sh38/segmentation_models/phase_cells/data/cell_cycle_down2/test_masks/0325.png is a low contrast image
# 0479.png
# /home/sh38/anaconda3/envs/proGAN_tf/lib/python3.6/site-packages/ipykernel_launcher.py:28: UserWarning: /home/sh38/segmentation_models/phase_cells/data/cell_cycle_down2/test_masks/0479.png is a low contrast image
# /home/sh38/anaconda3/envs/proGAN_tf/lib/python3.6/site-packages/ipykernel_launcher.py:28: UserWarning: /home/sh38/segmentation_models/phase_cells/data/cell_cycle_down2/test_images/0236.png is a low contrast image
# 0236.png
# /home/sh38/anaconda3/envs/proGAN_tf/lib/python3.6/site-packages/ipykernel_launcher.py:28: UserWarning: /home/sh38/segmentation_models/phase_cells/data/cell_cycle_down2/test_masks/0236.png is a low contrast image
# 0675.png
# /home/sh38/anaconda3/envs/proGAN_tf/lib/python3.6/site-packages/ipykernel_launcher.py:28: UserWarning: /home/sh38/segmentation_models/phase_cells/data/cell_cycle_down2/test_masks/0675.png is a low contrast image
# /home/sh38/anaconda3/envs/proGAN_tf/lib/python3.6/site-packages/ipykernel_launcher.py:28: UserWarning: /home/sh38/segmentation_models/phase_cells/data/cell_cycle_down2/test_images/0789.png is a low contrast image
# 0789.png
# /home/sh38/anaconda3/envs/proGAN_tf/lib/python3.6/site-packages/ipykernel_launcher.py:28: UserWarning: /home/sh38/segmentation_models/phase_cells/data/cell_cycle_down2/test_masks/0789.png is a low contrast image
# 0878.png
# /home/sh38/anaconda3/envs/proGAN_tf/lib/python3.6/site-packages/ipykernel_launcher.py:28: UserWarning: /home/sh38/segmentation_models/phase_cells/data/cell_cycle_down2/test_masks/0878.png is a low contrast image
# /home/sh38/anaconda3/envs/proGAN_tf/lib/python3.6/site-packages/ipykernel_launcher.py:28: UserWarning: /home/sh38/segmentation_models/phase_cells/data/cell_cycle_down2/test_images/0509.png is a low contrast image
# 0509.png
# /home/sh38/anaconda3/envs/proGAN_tf/lib/python3.6/site-packages/ipykernel_launcher.py:28: UserWarning: /home/sh38/segmentation_models/phase_cells/data/cell_cycle_down2/test_masks/0509.png is a low contrast image
# 0486.png
# /home/sh38/anaconda3/envs/proGAN_tf/lib/python3.6/site-packages/ipykernel_launcher.py:28: UserWarning: /home/sh38/segmentation_models/phase_cells/data/cell_cycle_down2/test_masks/0486.png is a low contrast image
# /home/sh38/anaconda3/envs/proGAN_tf/lib/python3.6/site-packages/ipykernel_launcher.py:28: UserWarning: /home/sh38/segmentation_models/phase_cells/data/cell_cycle_down2/test_images/0649.png is a low contrast image
# 0649.png
# /home/sh38/anaconda3/envs/proGAN_tf/lib/python3.6/site-packages/ipykernel_launcher.py:28: UserWarning: /home/sh38/segmentation_models/phase_cells/data/cell_cycle_down2/test_masks/0649.png is a low contrast image
# 0671.png
# /home/sh38/anaconda3/envs/proGAN_tf/lib/python3.6/site-packages/ipykernel_launcher.py:28: UserWarning: /home/sh38/segmentation_models/phase_cells/data/cell_cycle_down2/test_masks/0671.png is a low contrast image
# 0206.png
# /home/sh38/anaconda3/envs/proGAN_tf/lib/python3.6/site-packages/ipykernel_launcher.py:28: UserWarning: /home/sh38/segmentation_models/phase_cells/data/cell_cycle_down2/test_masks/0206.png is a low contrast image
# /home/sh38/anaconda3/envs/proGAN_tf/lib/python3.6/site-packages/ipykernel_launcher.py:28: UserWarning: /home/sh38/segmentation_models/phase_cells/data/cell_cycle_down2/test_images/0155.png is a low contrast image
# 0155.png
# /home/sh38/anaconda3/envs/proGAN_tf/lib/python3.6/site-packages/ipykernel_launcher.py:28: UserWarning: /home/sh38/segmentation_models/phase_cells/data/cell_cycle_down2/test_masks/0155.png is a low contrast image
# 0516.png
# /home/sh38/anaconda3/envs/proGAN_tf/lib/python3.6/site-packages/ipykernel_launcher.py:28: UserWarning: /home/sh38/segmentation_models/phase_cells/data/cell_cycle_down2/test_masks/0516.png is a low contrast image
# 0324.png
# /home/sh38/anaconda3/envs/proGAN_tf/lib/python3.6/site-packages/ipykernel_launcher.py:28: UserWarning: /home/sh38/segmentation_models/phase_cells/data/cell_cycle_down2/test_masks/0324.png is a low contrast image
# 0126.png
# /home/sh38/anaconda3/envs/proGAN_tf/lib/python3.6/site-packages/ipykernel_launcher.py:28: UserWarning: /home/sh38/segmentation_models/phase_cells/data/cell_cycle_down2/test_masks/0126.png is a low contrast image
# 0566.png
# /home/sh38/anaconda3/envs/proGAN_tf/lib/python3.6/site-packages/ipykernel_launcher.py:28: UserWarning: /home/sh38/segmentation_models/phase_cells/data/cell_cycle_down2/test_masks/0566.png is a low contrast image
# 0389.png
# /home/sh38/anaconda3/envs/proGAN_tf/lib/python3.6/site-packages/ipykernel_launcher.py:28: UserWarning: /home/sh38/segmentation_models/phase_cells/data/cell_cycle_down2/test_masks/0389.png is a low contrast image
# 0262.png
# /home/sh38/anaconda3/envs/proGAN_tf/lib/python3.6/site-packages/ipykernel_launcher.py:28: UserWarning: /home/sh38/segmentation_models/phase_cells/data/cell_cycle_down2/test_masks/0262.png is a low contrast image
# 0772.png
# /home/sh38/anaconda3/envs/proGAN_tf/lib/python3.6/site-packages/ipykernel_launcher.py:28: UserWarning: /home/sh38/segmentation_models/phase_cells/data/cell_cycle_down2/test_masks/0772.png is a low contrast image
# 0498.png
# /home/sh38/anaconda3/envs/proGAN_tf/lib/python3.6/site-packages/ipykernel_launcher.py:28: UserWarning: /home/sh38/segmentation_models/phase_cells/data/cell_cycle_down2/test_masks/0498.png is a low contrast image
# 0086.png
# /home/sh38/anaconda3/envs/proGAN_tf/lib/python3.6/site-packages/ipykernel_launcher.py:28: UserWarning: /home/sh38/segmentation_models/phase_cells/data/cell_cycle_down2/test_masks/0086.png is a low contrast image
# 0390.png
# /home/sh38/anaconda3/envs/proGAN_tf/lib/python3.6/site-packages/ipykernel_launcher.py:28: UserWarning: /home/sh38/segmentation_models/phase_cells/data/cell_cycle_down2/test_masks/0390.png is a low contrast image
# 0291.png
# /home/sh38/anaconda3/envs/proGAN_tf/lib/python3.6/site-packages/ipykernel_launcher.py:28: UserWarning: /home/sh38/segmentation_models/phase_cells/data/cell_cycle_down2/test_masks/0291.png is a low contrast image
# 0274.png
# /home/sh38/anaconda3/envs/proGAN_tf/lib/python3.6/site-packages/ipykernel_launcher.py:28: UserWarning: /home/sh38/segmentation_models/phase_cells/data/cell_cycle_down2/test_masks/0274.png is a low contrast image
# 0022.png
# /home/sh38/anaconda3/envs/proGAN_tf/lib/python3.6/site-packages/ipykernel_launcher.py:28: UserWarning: /home/sh38/segmentation_models/phase_cells/data/cell_cycle_down2/test_masks/0022.png is a low contrast image
# 0567.png
# /home/sh38/anaconda3/envs/proGAN_tf/lib/python3.6/site-packages/ipykernel_launcher.py:28: UserWarning: /home/sh38/segmentation_models/phase_cells/data/cell_cycle_down2/test_masks/0567.png is a low contrast image
# 0393.png
# /home/sh38/anaconda3/envs/proGAN_tf/lib/python3.6/site-packages/ipykernel_launcher.py:28: UserWarning: /home/sh38/segmentation_models/phase_cells/data/cell_cycle_down2/test_masks/0393.png is a low contrast image
# 0452.png
# /home/sh38/anaconda3/envs/proGAN_tf/lib/python3.6/site-packages/ipykernel_launcher.py:28: UserWarning: /home/sh38/segmentation_models/phase_cells/data/cell_cycle_down2/test_masks/0452.png is a low contrast image
# 0702.png
# /home/sh38/anaconda3/envs/proGAN_tf/lib/python3.6/site-packages/ipykernel_launcher.py:28: UserWarning: /home/sh38/segmentation_models/phase_cells/data/cell_cycle_down2/test_masks/0702.png is a low contrast image
# 0622.png
# /home/sh38/anaconda3/envs/proGAN_tf/lib/python3.6/site-packages/ipykernel_launcher.py:28: UserWarning: /home/sh38/segmentation_models/phase_cells/data/cell_cycle_down2/test_masks/0622.png is a low contrast image
# 0611.png
# /home/sh38/anaconda3/envs/proGAN_tf/lib/python3.6/site-packages/ipykernel_launcher.py:28: UserWarning: /home/sh38/segmentation_models/phase_cells/data/cell_cycle_down2/test_masks/0611.png is a low contrast image
# /home/sh38/anaconda3/envs/proGAN_tf/lib/python3.6/site-packages/ipykernel_launcher.py:28: UserWarning: /home/sh38/segmentation_models/phase_cells/data/cell_cycle_down2/test_images/0159.png is a low contrast image
# 0159.png
# /home/sh38/anaconda3/envs/proGAN_tf/lib/python3.6/site-packages/ipykernel_launcher.py:28: UserWarning: /home/sh38/segmentation_models/phase_cells/data/cell_cycle_down2/test_masks/0159.png is a low contrast image
# 0536.png
# /home/sh38/anaconda3/envs/proGAN_tf/lib/python3.6/site-packages/ipykernel_launcher.py:28: UserWarning: /home/sh38/segmentation_models/phase_cells/data/cell_cycle_down2/test_masks/0536.png is a low contrast image
# 0680.png
# /home/sh38/anaconda3/envs/proGAN_tf/lib/python3.6/site-packages/ipykernel_launcher.py:28: UserWarning: /home/sh38/segmentation_models/phase_cells/data/cell_cycle_down2/test_masks/0680.png is a low contrast image
# 0506.png
# /home/sh38/anaconda3/envs/proGAN_tf/lib/python3.6/site-packages/ipykernel_launcher.py:28: UserWarning: /home/sh38/segmentation_models/phase_cells/data/cell_cycle_down2/test_masks/0506.png is a low contrast image
# 0707.png
# /home/sh38/anaconda3/envs/proGAN_tf/lib/python3.6/site-packages/ipykernel_launcher.py:28: UserWarning: /home/sh38/segmentation_models/phase_cells/data/cell_cycle_down2/test_masks/0707.png is a low contrast image
# 0539.png
# /home/sh38/anaconda3/envs/proGAN_tf/lib/python3.6/site-packages/ipykernel_launcher.py:28: UserWarning: /home/sh38/segmentation_models/phase_cells/data/cell_cycle_down2/test_masks/0539.png is a low contrast image
# 0227.png
# /home/sh38/anaconda3/envs/proGAN_tf/lib/python3.6/site-packages/ipykernel_launcher.py:28: UserWarning: /home/sh38/segmentation_models/phase_cells/data/cell_cycle_down2/test_masks/0227.png is a low contrast image
# 0093.png
# /home/sh38/anaconda3/envs/proGAN_tf/lib/python3.6/site-packages/ipykernel_launcher.py:28: UserWarning: /home/sh38/segmentation_models/phase_cells/data/cell_cycle_down2/test_masks/0093.png is a low contrast image
# 0513.png
# /home/sh38/anaconda3/envs/proGAN_tf/lib/python3.6/site-packages/ipykernel_launcher.py:28: UserWarning: /home/sh38/segmentation_models/phase_cells/data/cell_cycle_down2/test_masks/0513.png is a low contrast image
# 0272.png
# /home/sh38/anaconda3/envs/proGAN_tf/lib/python3.6/site-packages/ipykernel_launcher.py:28: UserWarning: /home/sh38/segmentation_models/phase_cells/data/cell_cycle_down2/test_masks/0272.png is a low contrast image
# 0339.png
# /home/sh38/anaconda3/envs/proGAN_tf/lib/python3.6/site-packages/ipykernel_launcher.py:28: UserWarning: /home/sh38/segmentation_models/phase_cells/data/cell_cycle_down2/test_masks/0339.png is a low contrast image
# /home/sh38/anaconda3/envs/proGAN_tf/lib/python3.6/site-packages/ipykernel_launcher.py:28: UserWarning: /home/sh38/segmentation_models/phase_cells/data/cell_cycle_down2/test_images/0277.png is a low contrast image
# 0277.png
# /home/sh38/anaconda3/envs/proGAN_tf/lib/python3.6/site-packages/ipykernel_launcher.py:28: UserWarning: /home/sh38/segmentation_models/phase_cells/data/cell_cycle_down2/test_masks/0277.png is a low contrast image
# 0800.png
# /home/sh38/anaconda3/envs/proGAN_tf/lib/python3.6/site-packages/ipykernel_launcher.py:28: UserWarning: /home/sh38/segmentation_models/phase_cells/data/cell_cycle_down2/test_masks/0800.png is a low contrast image
# 0321.png
# /home/sh38/anaconda3/envs/proGAN_tf/lib/python3.6/site-packages/ipykernel_launcher.py:28: UserWarning: /home/sh38/segmentation_models/phase_cells/data/cell_cycle_down2/test_masks/0321.png is a low contrast image
# /home/sh38/anaconda3/envs/proGAN_tf/lib/python3.6/site-packages/ipykernel_launcher.py:28: UserWarning: /home/sh38/segmentation_models/phase_cells/data/cell_cycle_down2/test_images/0411.png is a low contrast image
# 0411.png
# /home/sh38/anaconda3/envs/proGAN_tf/lib/python3.6/site-packages/ipykernel_launcher.py:28: UserWarning: /home/sh38/segmentation_models/phase_cells/data/cell_cycle_down2/test_masks/0411.png is a low contrast image
# 0337.png
# /home/sh38/anaconda3/envs/proGAN_tf/lib/python3.6/site-packages/ipykernel_launcher.py:28: UserWarning: /home/sh38/segmentation_models/phase_cells/data/cell_cycle_down2/test_masks/0337.png is a low contrast image
# 0038.png
# /home/sh38/anaconda3/envs/proGAN_tf/lib/python3.6/site-packages/ipykernel_launcher.py:28: UserWarning: /home/sh38/segmentation_models/phase_cells/data/cell_cycle_down2/test_masks/0038.png is a low contrast image
# 0819.png
# /home/sh38/anaconda3/envs/proGAN_tf/lib/python3.6/site-packages/ipykernel_launcher.py:28: UserWarning: /home/sh38/segmentation_models/phase_cells/data/cell_cycle_down2/test_masks/0819.png is a low contrast image
# 0511.png
# /home/sh38/anaconda3/envs/proGAN_tf/lib/python3.6/site-packages/ipykernel_launcher.py:28: UserWarning: /home/sh38/segmentation_models/phase_cells/data/cell_cycle_down2/test_masks/0511.png is a low contrast image
# 0697.png
# /home/sh38/anaconda3/envs/proGAN_tf/lib/python3.6/site-packages/ipykernel_launcher.py:28: UserWarning: /home/sh38/segmentation_models/phase_cells/data/cell_cycle_down2/test_masks/0697.png is a low contrast image
# 0833.png
# /home/sh38/anaconda3/envs/proGAN_tf/lib/python3.6/site-packages/ipykernel_launcher.py:28: UserWarning: /home/sh38/segmentation_models/phase_cells/data/cell_cycle_down2/test_masks/0833.png is a low contrast image
# 0069.png
# /home/sh38/anaconda3/envs/proGAN_tf/lib/python3.6/site-packages/ipykernel_launcher.py:28: UserWarning: /home/sh38/segmentation_models/phase_cells/data/cell_cycle_down2/test_masks/0069.png is a low contrast image
# /home/sh38/anaconda3/envs/proGAN_tf/lib/python3.6/site-packages/ipykernel_launcher.py:28: UserWarning: /home/sh38/segmentation_models/phase_cells/data/cell_cycle_down2/test_images/0295.png is a low contrast image
# 0295.png
# /home/sh38/anaconda3/envs/proGAN_tf/lib/python3.6/site-packages/ipykernel_launcher.py:28: UserWarning: /home/sh38/segmentation_models/phase_cells/data/cell_cycle_down2/test_masks/0295.png is a low contrast image
# 0695.png
# /home/sh38/anaconda3/envs/proGAN_tf/lib/python3.6/site-packages/ipykernel_launcher.py:28: UserWarning: /home/sh38/segmentation_models/phase_cells/data/cell_cycle_down2/test_masks/0695.png is a low contrast image
# 0332.png
# /home/sh38/anaconda3/envs/proGAN_tf/lib/python3.6/site-packages/ipykernel_launcher.py:28: UserWarning: /home/sh38/segmentation_models/phase_cells/data/cell_cycle_down2/test_masks/0332.png is a low contrast image
# 0030.png
# /home/sh38/anaconda3/envs/proGAN_tf/lib/python3.6/site-packages/ipykernel_launcher.py:28: UserWarning: /home/sh38/segmentation_models/phase_cells/data/cell_cycle_down2/test_masks/0030.png is a low contrast image
# 0717.png
# /home/sh38/anaconda3/envs/proGAN_tf/lib/python3.6/site-packages/ipykernel_launcher.py:28: UserWarning: /home/sh38/segmentation_models/phase_cells/data/cell_cycle_down2/test_masks/0717.png is a low contrast image
# 0809.png
# /home/sh38/anaconda3/envs/proGAN_tf/lib/python3.6/site-packages/ipykernel_launcher.py:28: UserWarning: /home/sh38/segmentation_models/phase_cells/data/cell_cycle_down2/test_masks/0809.png is a low contrast image
# 0748.png
# /home/sh38/anaconda3/envs/proGAN_tf/lib/python3.6/site-packages/ipykernel_launcher.py:28: UserWarning: /home/sh38/segmentation_models/phase_cells/data/cell_cycle_down2/test_masks/0748.png is a low contrast image
# /home/sh38/anaconda3/envs/proGAN_tf/lib/python3.6/site-packages/ipykernel_launcher.py:28: UserWarning: /home/sh38/segmentation_models/phase_cells/data/cell_cycle_down2/test_images/0747.png is a low contrast image
# 0747.png
# /home/sh38/anaconda3/envs/proGAN_tf/lib/python3.6/site-packages/ipykernel_launcher.py:28: UserWarning: /home/sh38/segmentation_models/phase_cells/data/cell_cycle_down2/test_masks/0747.png is a low contrast image
# 0220.png
# /home/sh38/anaconda3/envs/proGAN_tf/lib/python3.6/site-packages/ipykernel_launcher.py:28: UserWarning: /home/sh38/segmentation_models/phase_cells/data/cell_cycle_down2/test_masks/0220.png is a low contrast image
# 0683.png
# /home/sh38/anaconda3/envs/proGAN_tf/lib/python3.6/site-packages/ipykernel_launcher.py:28: UserWarning: /home/sh38/segmentation_models/phase_cells/data/cell_cycle_down2/test_masks/0683.png is a low contrast image
# 0765.png
# /home/sh38/anaconda3/envs/proGAN_tf/lib/python3.6/site-packages/ipykernel_launcher.py:28: UserWarning: /home/sh38/segmentation_models/phase_cells/data/cell_cycle_down2/test_masks/0765.png is a low contrast image
# 0233.png
# /home/sh38/anaconda3/envs/proGAN_tf/lib/python3.6/site-packages/ipykernel_launcher.py:28: UserWarning: /home/sh38/segmentation_models/phase_cells/data/cell_cycle_down2/test_masks/0233.png is a low contrast image
# 0538.png
# /home/sh38/anaconda3/envs/proGAN_tf/lib/python3.6/site-packages/ipykernel_launcher.py:28: UserWarning: /home/sh38/segmentation_models/phase_cells/data/cell_cycle_down2/test_masks/0538.png is a low contrast image
# 0725.png
# /home/sh38/anaconda3/envs/proGAN_tf/lib/python3.6/site-packages/ipykernel_launcher.py:28: UserWarning: /home/sh38/segmentation_models/phase_cells/data/cell_cycle_down2/test_masks/0725.png is a low contrast image
# 0827.png
# /home/sh38/anaconda3/envs/proGAN_tf/lib/python3.6/site-packages/ipykernel_launcher.py:28: UserWarning: /home/sh38/segmentation_models/phase_cells/data/cell_cycle_down2/test_masks/0827.png is a low contrast image
# 0499.png
# /home/sh38/anaconda3/envs/proGAN_tf/lib/python3.6/site-packages/ipykernel_launcher.py:28: UserWarning: /home/sh38/segmentation_models/phase_cells/data/cell_cycle_down2/test_masks/0499.png is a low contrast image
# 0777.png
# /home/sh38/anaconda3/envs/proGAN_tf/lib/python3.6/site-packages/ipykernel_launcher.py:28: UserWarning: /home/sh38/segmentation_models/phase_cells/data/cell_cycle_down2/test_masks/0777.png is a low contrast image
# 0413.png
# /home/sh38/anaconda3/envs/proGAN_tf/lib/python3.6/site-packages/ipykernel_launcher.py:28: UserWarning: /home/sh38/segmentation_models/phase_cells/data/cell_cycle_down2/test_masks/0413.png is a low contrast image
# 0599.png
# /home/sh38/anaconda3/envs/proGAN_tf/lib/python3.6/site-packages/ipykernel_launcher.py:28: UserWarning: /home/sh38/segmentation_models/phase_cells/data/cell_cycle_down2/test_masks/0599.png is a low contrast image
# 0140.png
# /home/sh38/anaconda3/envs/proGAN_tf/lib/python3.6/site-packages/ipykernel_launcher.py:28: UserWarning: /home/sh38/segmentation_models/phase_cells/data/cell_cycle_down2/test_masks/0140.png is a low contrast image
# /home/sh38/anaconda3/envs/proGAN_tf/lib/python3.6/site-packages/ipykernel_launcher.py:28: UserWarning: /home/sh38/segmentation_models/phase_cells/data/cell_cycle_down2/test_images/0152.png is a low contrast image
# 0152.png
# /home/sh38/anaconda3/envs/proGAN_tf/lib/python3.6/site-packages/ipykernel_launcher.py:28: UserWarning: /home/sh38/segmentation_models/phase_cells/data/cell_cycle_down2/test_masks/0152.png is a low contrast image
# 0641.png
# /home/sh38/anaconda3/envs/proGAN_tf/lib/python3.6/site-packages/ipykernel_launcher.py:28: UserWarning: /home/sh38/segmentation_models/phase_cells/data/cell_cycle_down2/test_masks/0641.png is a low contrast image
# /home/sh38/anaconda3/envs/proGAN_tf/lib/python3.6/site-packages/ipykernel_launcher.py:28: UserWarning: /home/sh38/segmentation_models/phase_cells/data/cell_cycle_down2/test_images/0424.png is a low contrast image
# 0424.png
# /home/sh38/anaconda3/envs/proGAN_tf/lib/python3.6/site-packages/ipykernel_launcher.py:28: UserWarning: /home/sh38/segmentation_models/phase_cells/data/cell_cycle_down2/test_masks/0424.png is a low contrast image
# 0793.png
# /home/sh38/anaconda3/envs/proGAN_tf/lib/python3.6/site-packages/ipykernel_launcher.py:28: UserWarning: /home/sh38/segmentation_models/phase_cells/data/cell_cycle_down2/test_masks/0793.png is a low contrast image
# 0867.png
# /home/sh38/anaconda3/envs/proGAN_tf/lib/python3.6/site-packages/ipykernel_launcher.py:28: UserWarning: /home/sh38/segmentation_models/phase_cells/data/cell_cycle_down2/test_masks/0867.png is a low contrast image
# 0347.png
# /home/sh38/anaconda3/envs/proGAN_tf/lib/python3.6/site-packages/ipykernel_launcher.py:28: UserWarning: /home/sh38/segmentation_models/phase_cells/data/cell_cycle_down2/test_masks/0347.png is a low contrast image
# /home/sh38/anaconda3/envs/proGAN_tf/lib/python3.6/site-packages/ipykernel_launcher.py:28: UserWarning: /home/sh38/segmentation_models/phase_cells/data/cell_cycle_down2/test_images/0032.png is a low contrast image
# 0032.png
# /home/sh38/anaconda3/envs/proGAN_tf/lib/python3.6/site-packages/ipykernel_launcher.py:28: UserWarning: /home/sh38/segmentation_models/phase_cells/data/cell_cycle_down2/test_masks/0032.png is a low contrast image
# 0668.png
# /home/sh38/anaconda3/envs/proGAN_tf/lib/python3.6/site-packages/ipykernel_launcher.py:28: UserWarning: /home/sh38/segmentation_models/phase_cells/data/cell_cycle_down2/test_masks/0668.png is a low contrast image
# 0549.png
# /home/sh38/anaconda3/envs/proGAN_tf/lib/python3.6/site-packages/ipykernel_launcher.py:28: UserWarning: /home/sh38/segmentation_models/phase_cells/data/cell_cycle_down2/test_masks/0549.png is a low contrast image
# 0491.png
# /home/sh38/anaconda3/envs/proGAN_tf/lib/python3.6/site-packages/ipykernel_launcher.py:28: UserWarning: /home/sh38/segmentation_models/phase_cells/data/cell_cycle_down2/test_masks/0491.png is a low contrast image
# 0170.png
# /home/sh38/anaconda3/envs/proGAN_tf/lib/python3.6/site-packages/ipykernel_launcher.py:28: UserWarning: /home/sh38/segmentation_models/phase_cells/data/cell_cycle_down2/test_masks/0170.png is a low contrast image
# 0055.png
# /home/sh38/anaconda3/envs/proGAN_tf/lib/python3.6/site-packages/ipykernel_launcher.py:28: UserWarning: /home/sh38/segmentation_models/phase_cells/data/cell_cycle_down2/test_masks/0055.png is a low contrast image
# 0519.png
# /home/sh38/anaconda3/envs/proGAN_tf/lib/python3.6/site-packages/ipykernel_launcher.py:28: UserWarning: /home/sh38/segmentation_models/phase_cells/data/cell_cycle_down2/test_masks/0519.png is a low contrast image
# 0471.png
# /home/sh38/anaconda3/envs/proGAN_tf/lib/python3.6/site-packages/ipykernel_launcher.py:28: UserWarning: /home/sh38/segmentation_models/phase_cells/data/cell_cycle_down2/test_masks/0471.png is a low contrast image
# 0749.png
# /home/sh38/anaconda3/envs/proGAN_tf/lib/python3.6/site-packages/ipykernel_launcher.py:28: UserWarning: /home/sh38/segmentation_models/phase_cells/data/cell_cycle_down2/test_masks/0749.png is a low contrast image
# 0709.png
# /home/sh38/anaconda3/envs/proGAN_tf/lib/python3.6/site-packages/ipykernel_launcher.py:28: UserWarning: /home/sh38/segmentation_models/phase_cells/data/cell_cycle_down2/test_masks/0709.png is a low contrast image
# 0836.png
# /home/sh38/anaconda3/envs/proGAN_tf/lib/python3.6/site-packages/ipykernel_launcher.py:28: UserWarning: /home/sh38/segmentation_models/phase_cells/data/cell_cycle_down2/test_masks/0836.png is a low contrast image
# 0559.png
# /home/sh38/anaconda3/envs/proGAN_tf/lib/python3.6/site-packages/ipykernel_launcher.py:28: UserWarning: /home/sh38/segmentation_models/phase_cells/data/cell_cycle_down2/test_masks/0559.png is a low contrast image
# /home/sh38/anaconda3/envs/proGAN_tf/lib/python3.6/site-packages/ipykernel_launcher.py:28: UserWarning: /home/sh38/segmentation_models/phase_cells/data/cell_cycle_down2/test_images/0786.png is a low contrast image
# 0786.png
# /home/sh38/anaconda3/envs/proGAN_tf/lib/python3.6/site-packages/ipykernel_launcher.py:28: UserWarning: /home/sh38/segmentation_models/phase_cells/data/cell_cycle_down2/test_masks/0786.png is a low contrast image
# 0218.png
# /home/sh38/anaconda3/envs/proGAN_tf/lib/python3.6/site-packages/ipykernel_launcher.py:28: UserWarning: /home/sh38/segmentation_models/phase_cells/data/cell_cycle_down2/test_masks/0218.png is a low contrast image
# [0 1 2 3]

# %%
## downsample the training data
segmentation_data_folder = '/home/sh38/segmentation_models/phase_cells/data/cell_cycle/'
# train, val, test
subset = 'train'
images_folder = segmentation_data_folder+'{}_images/'.format(subset)
masks_folder = segmentation_data_folder+'{}_masks/'.format(subset)
print(images_folder); print(masks_folder)
train_image_files = glob.glob(images_folder+'*.png')
# for img_folder in train_image_folders:
# img_folder = train_image_folders[0]
_, ax = get_ax(5,2,5)
train_indices = np.random.randint(0, len(train_image_files), 5)
for i in range(len(train_indices)):
    train_image_file = train_image_files[train_indices[i]]
    img_id = os.path.basename(train_image_file)
    image_file = images_folder+'{}'.format(img_id); mask_file = masks_folder+'{}'.format(img_id)
    ax[i, 0].imshow(io.imread(image_file)); ax[i, 1].imshow(io.imread(mask_file))
    mask_image = io.imread(mask_file)
    print(type(mask_image))
    print(np.unique(mask_image))
